# %%
""" Wine Quality analysis project
===================================
a comprehensive data analysis project answering 30 questions about the wine Quality

Dataset : wine Quality Dataset(Red and white wines)
Features : chemical properties(acidity, sugar, alcohol, etc.)
Target : Quality ratings(0 - 10)
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings 
warnings.filter
